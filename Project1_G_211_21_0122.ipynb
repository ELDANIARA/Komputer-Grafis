# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt

# %%
dt = pd.read_csv('https://raw.githubusercontent.com/ELDANIARA/Komputer-Grafis/main/retail_raw_reduced.csv')
dt
# Out:
#       order_id  order_date  customer_id             city     province  \
# 0      1703458  2019-10-17        14004  Jakarta Selatan  DKI Jakarta
# 1      1706815  2019-10-24        17220  Jakarta Selatan  DKI Jakarta
# 2      1710718  2019-11-03        16518    Jakarta Utara  DKI Jakarta
# 3      1683592  2019-08-19        16364    Jakarta Barat  DKI Jakarta
# 4      1702573  2019-10-16        15696    Jakarta Timur  DKI Jakarta
# ...        ...         ...          ...              ...          ...
# 4995   1724011  2019-12-01        12838        Tangerang       Banten
# 4996   1676302  2019-07-28        13833            Bogor   Jawa Barat
# 4997   1706071  2019-10-23        16332    Jakarta Timur  DKI Jakarta
# 4998   1703620  2019-10-17        13055    Jakarta Barat  DKI Jakarta
# 4999   1720036  2019-11-24        17609    Jakarta Pusat  DKI Jakarta
#
#      product_id    brand  quantity  item_price
# 0         P1910  BRAND_J        10      740000
# 1         P2934  BRAND_R         2      604000
# 2         P0908  BRAND_C         8     1045000
# 3         P0128  BRAND_A         4      205000
# 4         P2968  BRAND_R         2     4475000
# ...         ...      ...       ...         ...
# 4995      P3047  BRAND_R         2      450000
# 4996      P0760  BRAND_C         3     1465000
# 4997      P1681  BRAND_H         4      747000
# 4998      P0757  BRAND_C         8      695000
# 4999      P3334  BRAND_S         1     1045000
#
# [5000 rows x 9 columns]

# %%
dt['order_month'] = dt['order_date'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d").strftime('%Y-%m'))

# %%
dt['gmv'] = dt['item_price'] * dt['quantity']

# %%
plt.figure(figsize=(10, 5))
dt[dt['order_month']=='2019-12'].groupby(['order_date'])['customer_id'].nunique().plot(color='green', marker='.', linewidth=2)
plt.title('Daily Number of Customers - December 2019', loc='center', pad=25, fontsize=15, color='violet')
plt.xlabel('Order Date', fontsize=10, color='blue')
plt.ylabel('Number of Customers', fontsize=10, color='red')
plt.grid(color='darkgray', linestyle=':', linewidth=0.5)
plt.ylim(ymin=0)
# Out:
# (0.0, 41.05)

# %% [markdown]
# **Case 1 Menentukan Brand Top 5**

# %%
#mengambil informasi top 5 brands berdasarkan quantity
top_brands = (dt[dt['order_month']=='2019-12'].groupby('brand')['quantity']
                .sum()
                .reset_index()
                .sort_values(by='quantity',ascending=False)
                .head(5))
#membuat dataframe baru, filter hanya di bulan Desember 2019 dan hanya top 5 brands
dataset_top5brand_dec = dt[(dt['order_month']=='2019-12') & (dt['brand'].isin(top_brands['brand'].to_list()))]
# print top brands
print(top_brands)
# Out:
#      brand  quantity
# 8  BRAND_S      2197
# 6  BRAND_P      2194
# 7  BRAND_R      1508
# 2  BRAND_C      1365
# 0  BRAND_A      1315

# %% [markdown]
# **Case 2 Multi-line chart daily quantity untuk brand top 5**

# %%
dataset_top5brand_dec.groupby(['order_date','brand'])['quantity'].sum().unstack().plot(marker='.', cmap='plasma')
plt.title('Daily Sold Quantity Dec 2019-Breakdown by Brands',loc='center',pad=20, fontsize=15, color='blue')
plt.xlabel('Order Date', fontsize = 10, color='green')
plt.ylabel('Quantity',fontsize = 10, color='red')
plt.grid(color='darkgray', linestyle=':', linewidth=0.5)
plt.ylim(ymin=0)
plt.legend(loc='upper center', bbox_to_anchor=(1.1, 1), shadow=True, ncol=1)
plt.annotate('Terjadi lonjakan', xy=(7, 310), xytext=(8, 300),
             weight='bold', color='orange',
             arrowprops=dict(arrowstyle='->',
                             connectionstyle="arc3",
                             color='brown'))
plt.gcf().set_size_inches(10, 5)
plt.tight_layout()

# %% [markdown]
# **Case 3 menentukan jumlah product untuk masing-masing brand yang laku selama bulan Desember 2019.**

# %%
plt.clf()
dataset_top5brand_dec.groupby('brand')['product_id'].nunique().sort_values(ascending=False).plot(kind='bar', color='violet')
plt.title('Number of Sold Products per Brand, December 2019',loc='center',pad=20, fontsize=15, color='brown')
plt.xlabel('Brand', fontsize = 10, color='magenta')
plt.ylabel('Number of Products',fontsize = 10, color='lightblue')
plt.ylim(ymin=0)
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'BRAND_S'),
#   Text(1, 0, 'BRAND_P'),
#   Text(2, 0, 'BRAND_R'),
#   Text(3, 0, 'BRAND_C'),
#   Text(4, 0, 'BRAND_A')])

# %% [markdown]
# **Case 4 Penjualan produk diatas 100 dan dibawah 100 selama Desember 2019
# Gunakan stacked chart**

# %% [markdown]
# Membuat dataframe baru, untuk agregat jumlah quantity terjual per product

# %%
dataset_top5brand_dec_per_product = dataset_top5brand_dec.groupby(['brand','product_id'])['quantity'].sum().reset_index()

# %% [markdown]
# beri kolom baru untuk menandai product yang terjual >= 100 dan <100

# %%
dataset_top5brand_dec_per_product['quantity_group'] = dataset_top5brand_dec_per_product['quantity'].apply(lambda x: '>= 100' if x>=100 else '< 100')
dataset_top5brand_dec_per_product.sort_values('quantity',ascending=False,inplace=True)

# %% [markdown]
# membuat referensi pengurutan brand berdasarkan banyaknya semua product

# %%
s_sort = dataset_top5brand_dec_per_product.groupby('brand')['product_id'].nunique().sort_values(ascending=False)

# %% [markdown]
# plot stacked barchart

# %%
dataset_top5brand_dec_per_product.groupby(['brand','quantity_group'])['product_id'].nunique().reindex(index=s_sort.index, level='brand').unstack().plot(kind='bar', stacked=True)
plt.title('Number of Sold Products per Brand, December 2019',loc='center',pad=30, fontsize=11, color='red')
plt.xlabel('Brand', fontsize = 7, color='pink')
plt.ylabel('Number of Products',fontsize = 7, color='grey')
plt.ylim(ymin=0)
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'BRAND_S'),
#   Text(1, 0, 'BRAND_P'),
#   Text(2, 0, 'BRAND_R'),
#   Text(3, 0, 'BRAND_C'),
#   Text(4, 0, 'BRAND_A')])

# %% [markdown]
# **Case 5 Gunakan histogram untuk melihat distribusi harga product-product yang ada di top 5 brand**

# %%
plt.figure(figsize=(15,5))
plt.hist(dataset_top5brand_dec.groupby('product_id')['item_price'].median(), bins=10, stacked=True, range=(1,2000000), color='lightgreen')
plt.title('Distribution of Price Median per Product\nTop 5 Brands in Dec 2019',fontsize=10, color='brown')
plt.xlabel('Price Median', fontsize = 7, color='lightblue')
plt.ylabel('Number of Products',fontsize = 7, color='lightgrey')
plt.xlim(xmin=0,xmax=2000000)
# Out:
# (0.0, 2000000.0)

# %% [markdown]
# **Case 6A Korelasi quantity vs GMV**

# %%
#agregat per product
data_per_product_top5brand_dec = dataset_top5brand_dec.groupby('product_id').agg({'quantity': 'sum', 'gmv':'sum', 'item_price':'median'}).reset_index()
#scatter plot
plt.figure(figsize=(15,8))
plt.scatter(data_per_product_top5brand_dec['quantity'],data_per_product_top5brand_dec['gmv'], marker='+', color='lightblue')
plt.title('Correlation of Quantity and GMV per Product\nTop 5 Brands in December 2019',fontsize=10, color='darkred')
plt.xlabel('Quantity', fontsize = 7, color='blue')
plt.ylabel('GMV (in Millions)',fontsize = 7, color='blue')
plt.xlim(xmin=0,xmax=300)
plt.ylim(ymin=0,ymax=200000000)
labels, locations = plt.yticks()
plt.yticks(labels, (labels/1000000).astype(int))
# Out:
# ([<matplotlib.axis.YTick at 0x7f9e77ecb580>,
#   <matplotlib.axis.YTick at 0x7f9e77ecbac0>,
#   <matplotlib.axis.YTick at 0x7f9e77ecb3d0>,
#   <matplotlib.axis.YTick at 0x7f9e77f2b5b0>,
#   <matplotlib.axis.YTick at 0x7f9e77f2baf0>,
#   <matplotlib.axis.YTick at 0x7f9e77f60310>,
#   <matplotlib.axis.YTick at 0x7f9e77f60af0>,
#   <matplotlib.axis.YTick at 0x7f9e77f612d0>,
#   <matplotlib.axis.YTick at 0x7f9e77f61ab0>],
#  [Text(0, 0.0, '0'),
#   Text(0, 25000000.0, '25'),
#   Text(0, 50000000.0, '50'),
#   Text(0, 75000000.0, '75'),
#   Text(0, 100000000.0, '100'),
#   Text(0, 125000000.0, '125'),
#   Text(0, 150000000.0, '150'),
#   Text(0, 175000000.0, '175'),
#   Text(0, 200000000.0, '200')])

# %% [markdown]
# **Case 6B  Korelasi median harga vs quantity**

# %%
import matplotlib.pyplot as plt
plt.clf()
#agregat per product
data_per_product_top5brand_dec = dataset_top5brand_dec.groupby('product_id').agg({'quantity': 'sum', 'gmv':'sum', 'item_price':'median'}).reset_index()
#scatter plot
plt.figure(figsize=(15,8))
plt.scatter(data_per_product_top5brand_dec['item_price'],data_per_product_top5brand_dec['quantity'], marker='o', color='lightgreen')
plt.title('Correlation of Quantity and GMV per Product\n Top 5 Brands in December 2019',fontsize=10, color='darkred')
plt.xlabel('Price Median', fontsize = 7, color='blue')
plt.ylabel('Quantity',fontsize = 7, color='blue')
plt.xlim(xmin=0,xmax=2000000)
plt.ylim(ymin=0,ymax=250)
# Out:
# (0.0, 250.0)
